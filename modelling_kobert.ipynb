# %%
import pandas as pd
non = pd.read_csv('Final_book_details_271.csv')
non2 = pd.read_csv('Final_book_details_272.csv')
non3 = pd.read_csv('Final_book_details_273.csv')
non4 = pd.read_csv('Final_book_details_274.csv')
non5 = pd.read_csv('Final_book_details_275.csv')
non5
# Out:
# /tmp/ipykernel_479209/1065816456.py:5: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   non4 = pd.read_csv('Final_book_details_274.csv')
#        index                 도서 이름  \
# 0      55364   부와 행운을 끌어당기는 우주의 법칙
# 1      55365        우리는 책 읽는 가족입니다
# 2      55366   1년에 200권 읽으면 일어나는 일
# 3      55367        우리 직업은 미래형이라서요
# 4      55368        내가 처음 뇌를 열었을 때
# ...      ...                   ...
# 17784  76788                 회복탄력성
# 17785  76789     한 달이라도 좋아, 보홀이라면!
# 17786  76790                호감의 시작
# 17787  76791          봄이 오고 그대가 가다
# 17788  76792  스물일곱, 과일로 쏘아 올린 200억
#
#                                                      줄거리    장르           출판사  \
# 0      “ 무일푼, 무스펙에서 경제적 자유를 이룬젊은 부자 김도사 권마담 부부의성공과 부,...  자기계발         굿웰스북스
# 1      “독서, 이제는 온가족이 함께 하라!”행복한 가족을 만들고 싶다면 함께 독서하라!“...  자기계발  미다스북스(리틀미다스)
# 2      책을 읽는 방법을 바꾸자삶의 많은 것들이 바뀌기 시작했다!“책을 읽으면 대체 뭐가 ...  자기계발  미다스북스(리틀미다스)
# ...

# %%
df_non_ = pd.concat([non, non2, non3, non4, non5])
df_non_
# Out:
#        index                 도서 이름  \
# 0          0                 총 균 쇠
# 1          1                    숙론
# 2          2             친애하는 슐츠 씨
# 3          3  가난한 아이들은 어떻게 어른이 되는가
# 4          4                 팩트풀니스
# ...      ...                   ...
# 17784  76788                 회복탄력성
# 17785  76789     한 달이라도 좋아, 보홀이라면!
# 17786  76790                호감의 시작
# 17787  76791          봄이 오고 그대가 가다
# 17788  76792  스물일곱, 과일로 쏘아 올린 200억
#
#                                                      줄거리     장르           출판사  \
# 0      문명의 생성과 번영의 수수께끼를 밝힌 세계적 명저마침내 만나는 출간 25년 기념 뉴...     인문           김영사
# 1      “누가 옳은가가 아니라 무엇이 옳은가를 찾으려는 것이다”통섭의 과학자 최재천 교수가...     인문           김영사
# 2      “얼마나 많은 차별이 무지에서 비롯되는가?[피너츠]의 첫 흑인 캐릭터부터 여자 옷의...     인문          어크로스
# 3      “처음 만날 때는 열예닐곱 살의 청소년이었던 이들이지금은 서른 즈음의 청년이 되었다...  사회 정치           돌베개
# 4      빌 게이츠가 미국 모든 대학 졸업생에게 직접 선물한 화제의 책강력한 사실을 바탕으로...     인문           김영사
# ...

# %%
df_non_.isnull().sum()
# Out:
# index         0
# 도서 이름         0
# 줄거리           0
# 장르            0
# 출판사          70
# 작가          111
# 판매지수     213934
# 판매가           0
# ID            0
# month         0
# best          0
# dtype: int64

# %%
df_non_2 = df_non_

# %%
# '도서 이름' 열에 결측치가 있는 행을 삭제
df_non_ = df_non_.dropna(subset=['작가'])

# 결과 확인
df_non_
# Out:
#        index                 도서 이름  \
# 0          0                 총 균 쇠
# 1          1                    숙론
# 2          2             친애하는 슐츠 씨
# 3          3  가난한 아이들은 어떻게 어른이 되는가
# 4          4                 팩트풀니스
# ...      ...                   ...
# 17784  76788                 회복탄력성
# 17785  76789     한 달이라도 좋아, 보홀이라면!
# 17786  76790                호감의 시작
# 17787  76791          봄이 오고 그대가 가다
# 17788  76792  스물일곱, 과일로 쏘아 올린 200억
#
#                                                      줄거리     장르           출판사  \
# 0      문명의 생성과 번영의 수수께끼를 밝힌 세계적 명저마침내 만나는 출간 25년 기념 뉴...     인문           김영사
# 1      “누가 옳은가가 아니라 무엇이 옳은가를 찾으려는 것이다”통섭의 과학자 최재천 교수가...     인문           김영사
# 2      “얼마나 많은 차별이 무지에서 비롯되는가?[피너츠]의 첫 흑인 캐릭터부터 여자 옷의...     인문          어크로스
# 3      “처음 만날 때는 열예닐곱 살의 청소년이었던 이들이지금은 서른 즈음의 청년이 되었다...  사회 정치           돌베개
# 4      빌 게이츠가 미국 모든 대학 졸업생에게 직접 선물한 화제의 책강력한 사실을 바탕으로...     인문           김영사
# ...

# %%
import pandas as pd
date = pd.read_csv('date_final_df.csv')
date
# Out:
#                   출간일         ID
# 0       2023년 05월 10일  118755085
# 1       2024년 05월 10일  126395984
# 2       2024년 06월 03일  126791092
# 3       2023년 11월 06일  123317793
# 4       2019년 03월 08일   69724044
# ...               ...        ...
# 297673  2027년 07월 24일  128920663
# 297674  2024년 07월 24일  128920777
# 297675  2024년 07월 23일  128928568
# 297676  2024년 07월 10일  128928919
# 297677  2024년 07월 15일  128930900
#
# [297678 rows x 2 columns]

# %%
# '출간일'을 날짜 형식으로 변환
date['출간일'] = pd.to_datetime(date['출간일'], format='%Y년 %m월 %d일')

# %%
date['year'] = date['출간일'].dt.year
date['month'] = date['출간일'].dt.month
date
# Out:
#               출간일         ID    year  month
# 0      2023-05-10  118755085  2023.0    5.0
# 1      2024-05-10  126395984  2024.0    5.0
# 2      2024-06-03  126791092  2024.0    6.0
# 3      2023-11-06  123317793  2023.0   11.0
# 4      2019-03-08   69724044  2019.0    3.0
# ...           ...        ...     ...    ...
# 297673 2027-07-24  128920663  2027.0    7.0
# 297674 2024-07-24  128920777  2024.0    7.0
# 297675 2024-07-23  128928568  2024.0    7.0
# 297676 2024-07-10  128928919  2024.0    7.0
# 297677 2024-07-15  128930900  2024.0    7.0
#
# [297678 rows x 4 columns]

# %%
date['year'].unique()
# Out:
# array([2023., 2024., 2019., 2016., 2012., 2021., 2022., 2017., 2018.,
#        2004., 2014., 2020., 2010., 2015., 2008., 2013., 2009., 2007.,
#        2011., 2002., 2006., 2003., 2001., 2005., 2000., 1999., 1997.,
#          nan, 1989., 1996., 1994., 1998., 1995., 1978., 1993., 1985.,
#        1991., 1987., 1992., 1981., 1988., 1990., 1986., 1980., 1982.,
#        1975., 1983., 1979., 1984., 1976., 1961., 1977., 1970., 1974.,
#        1973., 1969., 2027.])

# %%
df_non_['year'] = date['year']
df_non_
# Out:
# /tmp/ipykernel_479209/3703781358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_['year'] = date['year']
#        index                 도서 이름  \
# 0          0                 총 균 쇠
# 1          1                    숙론
# 2          2             친애하는 슐츠 씨
# 3          3  가난한 아이들은 어떻게 어른이 되는가
# 4          4                 팩트풀니스
# ...      ...                   ...
# 17784  76788                 회복탄력성
# 17785  76789     한 달이라도 좋아, 보홀이라면!
# 17786  76790                호감의 시작
# 17787  76791          봄이 오고 그대가 가다
# 17788  76792  스물일곱, 과일로 쏘아 올린 200억
#
#                                                      줄거리     장르           출판사  \
# 0      문명의 생성과 번영의 수수께끼를 밝힌 세계적 명저마침내 만나는 출간 25년 기념 뉴...     인문           김영사
# ...

# %%
df_non_.isnull().sum()
# Out:
# index         0
# 도서 이름         0
# 줄거리           0
# 장르            0
# 출판사          70
# 작가            0
# 판매지수     213838
# 판매가           0
# ID            0
# month         0
# best          0
# year        126
# dtype: int64

# %%
df_non_sorted = df_non_.sort_values(by='year', ascending=False)
df_non_sorted
# Out:
#        index             도서 이름  \
# 65517  18258  세상에서 제일 이상한 그 아이
# 20093  36449   클리어 The CLEAR 1
# 45319  55558    노동조합 100문 100답
# 20123  36480               미인계
# 45320  55559      생활 속 법률 상식사전
# ...      ...               ...
# 2671   58626    기시미 이치로의 삶과 죽음
# 6538   63147          아무튼, 피아노
# 6724   63375     난세를 살아가는 지략 2
# 10520  68144     생각의 끈 (큰글자도서)
# 15940  74600        성과관리 답을 찾다
#
#                                                      줄거리        장르  \
# 65517  독특한 스토리 전개로 일본에서 발간 당시 라이트노벨 독자들 사이에서 화제가 됐던 작...  만화/라이트노벨
# 20093  마법대륙 사이드리아에 마법사의 천적이 등장했다!대항마법사 사드!!!사드의 대항마법 ...   소설/시/희곡
# 45319  『노동조합 100문 100답』개정2판은 2020년 12월 개정된 노조법을 반영202...     사회 정치
# 20123  중국 춘추시대 월나라의 서시를 비롯하여 당나라 양귀비까지 중국역사상 가장 아름답다고...   소설/시/희곡
# 45320  근처 변호사 사무실이 어디에 있었나하는 생각이 간절해지는 순간,하얘지는 머리, 새까...     사회 정치
# ...                                                  ...       ...
# 2671   인생은 진화가 아니라 변화다! 젊음과 늙음, 건강과 질병에 우열은 없다!기시미 이치...        인문
# ...

# %%
df_non_sorted = df_non_sorted.dropna(subset=['year'])
df_non_sorted
# Out:
#        index             도서 이름  \
# 65517  18258  세상에서 제일 이상한 그 아이
# 20093  36449   클리어 The CLEAR 1
# 45319  55558    노동조합 100문 100답
# 20123  36480               미인계
# 45320  55559      생활 속 법률 상식사전
# ...      ...               ...
# 36984  18564       사랑받지 못한 어글리
# 26155  42808              파란 3
# 26155  62387        아인슈타인의 달팽이
# 26155   7133     유망 아르바이트 백과사전
# 26155  29804         도시의 정치경제학
#
#                                                      줄거리        장르  \
# 65517  독특한 스토리 전개로 일본에서 발간 당시 라이트노벨 독자들 사이에서 화제가 됐던 작...  만화/라이트노벨
# 20093  마법대륙 사이드리아에 마법사의 천적이 등장했다!대항마법사 사드!!!사드의 대항마법 ...   소설/시/희곡
# 45319  『노동조합 100문 100답』개정2판은 2020년 12월 개정된 노조법을 반영202...     사회 정치
# 20123  중국 춘추시대 월나라의 서시를 비롯하여 당나라 양귀비까지 중국역사상 가장 아름답다고...   소설/시/희곡
# 45320  근처 변호사 사무실이 어디에 있었나하는 생각이 간절해지는 순간,하얘지는 머리, 새까...     사회 정치
# ...                                                  ...       ...
# 36984  갖은 고난과 역경을 이겨내고영국 최초의 흑인 여성판사가 된 한 소녀의 이야기영국 최...       에세이
# ...

# %%
df_non_sorted['장르'].unique()
# Out:
# array(['만화/라이트노벨', '소설/시/희곡', '사회 정치', '에세이', '인문', '자기계발', '경제 경영',
#        '청소년', 'IT 모바일', '대학교재', '잡지', '건강 취미', '예술', '여행', '국어 외국어 사전',
#        '어린이', '역사', '자연과학', '종교', '가정 살림', '수험서 자격증', '유아', '인물', '일본도서',
#        '오디오북', '소설', '디자인문구', '중고 국내도서', '경영/인문', 'BOOKK(부크크)', '중고등참고서',
#        '초등참고서'], dtype=object)

# %%
# 추출할 장르 목록
genres_to_extract = ['사회 정치', '소설/시/희곡', '에세이', '자기계발']

# 장르 열이 지정된 값 중 하나인 행만 추출
df_non_sorted = df_non_sorted[df_non_sorted['장르'].isin(genres_to_extract)]

# 결과 출력
print("Filtered Book Details:")
df_non_sorted
# Out:
# Filtered Book Details:
#        index            도서 이름  \
# 20093  36449  클리어 The CLEAR 1
# 45319  55558   노동조합 100문 100답
# 20123  36480              미인계
# 45320  55559     생활 속 법률 상식사전
# 45325  55565      상속재산 분할심판청구
# ...      ...              ...
# 36984  18564      사랑받지 못한 어글리
# 26155  42808             파란 3
# 26155  62387       아인슈타인의 달팽이
# 26155   7133    유망 아르바이트 백과사전
# 26155  29804        도시의 정치경제학
#
#                                                      줄거리       장르     출판사  \
# 20093  마법대륙 사이드리아에 마법사의 천적이 등장했다!대항마법사 사드!!!사드의 대항마법 ...  소설/시/희곡      동아
# 45319  『노동조합 100문 100답』개정2판은 2020년 12월 개정된 노조법을 반영202...    사회 정치  매일노동뉴스
# 20123  중국 춘추시대 월나라의 서시를 비롯하여 당나라 양귀비까지 중국역사상 가장 아름답다고...  소설/시/희곡    오디북스
# 45320  근처 변호사 사무실이 어디에 있었나하는 생각이 간절해지는 순간,하얘지는 머리, 새까...    사회 정치      길벗
# 45325  이번 개정판에서는 상속재산분할, 유류분반환청구 등에 관하여 2020년 3월 이후 선...    사회 정치   지혜와지식
# ...                                                  ...      ...     ...
# ...

# %%
df_non_sorted['장르'].unique()
# Out:
# array(['소설/시/희곡', '사회 정치', '에세이', '자기계발'], dtype=object)

# %%
year_counts = df_non_sorted.groupby('year').size()
year_counts
# Out:
# year
# 1975.0        4
# 1978.0       13
# 1979.0        4
# 1980.0        8
# 1981.0        4
# 1982.0        6
# 1983.0        4
# 1985.0       30
# 1986.0       18
# 1987.0       35
# 1988.0       12
# 1989.0       53
# 1990.0      100
# 1991.0      120
# 1992.0      146
# 1993.0      235
# 1994.0      310
# 1995.0      492
# 1996.0      457
# 1997.0      906
# 1998.0     1256
# 1999.0     2218
# 2000.0     3400
# 2001.0     3055
# 2002.0     3779
# 2003.0     4125
# 2004.0     6778
# 2005.0     6731
# 2006.0     8610
# 2007.0     9935
# 2008.0    10772
# 2009.0    12363
# 2010.0    12168
# 2011.0    12860
# 2012.0    14038
# 2013.0    11685
# 2014.0    11689
# 2015.0    11160
# 2016.0    10682
# 2017.0    12024
# 2018.0    16253
# 2019.0    15370
# 2020.0    15967
# 2021.0    15425
# 2022.0    14876
# 2023.0    15450
# 2024.0     7689
# dtype: int64

# %% [markdown]
# except_2024

# %%
df_non_sorted = df_non_sorted[df_non_sorted['year'] != 2024]
df_non_sorted
# Out:
#        index          도서 이름  \
# 11853  61041   나는 야한 여자가 좋다
# 51555  63780      뱀파이어의 별 2
# 51292  33906        수거물 폐기물
# 53713  36582         군인의 품격
# 54414  66804            무녀굴
# ...      ...            ...
# 36984  18564    사랑받지 못한 어글리
# 26155  42808           파란 3
# 26155  62387     아인슈타인의 달팽이
# 26155   7133  유망 아르바이트 백과사전
# 26155  29804      도시의 정치경제학
#
#                                                      줄거리       장르    출판사  \
# 11853  도덕보다는 본능을, 이성보다는 감성을쉽고 재미있게 읽히는 경쾌한 에세이, 21년만의...      에세이    북리뷰
# 51555  '뱀파이어의 꽃' 그 마지막 입맞춤,영원불멸의 뱀파이어 로맨스!‘말해서는 안 돼. ...  소설/시/희곡   테라스북
# 51292  ■ 사랑의 기억을 모으고 나누고 버리고… 마음이 심플해지는 감정정리법!-카피라이터 ...      에세이   폭스코너
# 53713  군인엄마의, 희망군대 만들기 프로젝트아들에게도 엄마에게도, 637일간의 인생수업대한...      에세이    더블엔
# 54414  <한국 공포 문학 단편선>에 꾸준히 단편을 발표해 오며 실력을 닦아 온 신진오 작가...  소설/시/희곡   황금가지
# ...                                                  ...      ...    ...
# 36984  갖은 고난과 역경을 이겨내고영국 최초의 흑인 여성판사가 된 한 소녀의 이야기영국 최...      에세이  오픈하우스
# ...

# %%
df_non_sorted = df_non_sorted[df_non_sorted['year'] >= 2017]
df_non_sorted
# Out:
#        index         도서 이름                                                줄거리  \
# 11853  61041  나는 야한 여자가 좋다  도덕보다는 본능을, 이성보다는 감성을쉽고 재미있게 읽히는 경쾌한 에세이, 21년만의...
# 51555  63780     뱀파이어의 별 2  '뱀파이어의 꽃' 그 마지막 입맞춤,영원불멸의 뱀파이어 로맨스!‘말해서는 안 돼. ...
# 51292  33906       수거물 폐기물  ■ 사랑의 기억을 모으고 나누고 버리고… 마음이 심플해지는 감정정리법!-카피라이터 ...
# 53713  36582        군인의 품격  군인엄마의, 희망군대 만들기 프로젝트아들에게도 엄마에게도, 637일간의 인생수업대한...
# 54414  66804           무녀굴  <한국 공포 문학 단편선>에 꾸준히 단편을 발표해 오며 실력을 닦아 온 신진오 작가...
# ...      ...           ...                                                ...
# 8570   65655  자기계발 코칭전문가 4  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 29816  68589      모두가 예술이다  계간 문예지 『시와세계』와 『현대불교신문』이 공동으로 제정한 <이상시문학상>은 시인...
# 8573   65658  자기계발 코칭전문가 1  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 8569   65654  자기계발 코칭전문가 5  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 6391   31192       이상 시 전집  한국문학사에서 유례를 찾기 힘들 만큼 실험적이고 전위적인 문학적 조형 언어로 ‘시각...
#
# ...

# %%
df_non_sorted[df_non_sorted['best'] == 'Y']
# Out:
#        index             도서 이름  \
# 51188  33777            합리적 남자
# 9847   58849     받은 만큼 복수하는 소녀
# 11831  61019    나, 있는 그대로 참 좋다
# 54459  66850           비탄의 문 1
# 54458  66849           비탄의 문 2
# ...      ...               ...
# 6385   31185           없음의 대명사
# 6305    6903                 풀
# 6378   31177                풀꽃
# 6392   31193  꽃샘바람에 흔들린다면 너는 꽃
# 6436   31239           수학자의 아침
#
#                                                      줄거리       장르     출판사  \
# 51188  남자와 여자가 짝짓기 대상을 선택하는 방식이 다른 것은 인간의 DNA에 깊이 새겨져...     자기계발     아니마
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡    문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이    허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# ...                                                  ...      ...     ...
# ...

# %% [markdown]
# 베스트 셀러 생애주기

# %%
df_book_details = pd.read_csv('book_details.csv')

# %%
df_book_details
# Out:
#                                    도서 이름  \
# 0                              나의 영어 사춘기
# 1                              신경 끄기의 기술
# 2                               82년생 김지영
# 3                                 언어의 온도
# 4                            랩걸 Lab Girl
# ...                                  ...
# 77400     2024 해커스군무원 혜원국어 실전동형모의고사 20회분
# 77401           2024 유휘운 행정법총론 실전동형 모의고사
# 77402  ETS 토익 정기시험 실전 1000 Vol. 1 RC(리딩)
# 77403                 나혼자 끝내는 독학 일본어 첫걸음
# 77404                      해리포터와 비밀의 방 1
#
#                                                      줄거리         장르  \
# 0      대한민국 대표 영어강사 이시원, 영포자들의 닫힌 말문을 열게하다!8주면 누구나 영어...  국어 외국어 사전
# 1      아마존·뉴욕타임스 베스트셀러 1위150만 부 돌파! 아마존 53주 연속 베스트셀러2...       자기계발
# 2      공포, 피로, 당황, 놀람, 혼란, 좌절의 연속에 대한 한국 여자의 인생 현장 보고...    소설/시/희곡
# 3      “말과 글에는 나름의 온도가 있다”말과 글에는 나름의 온도가 있다. 따뜻함과 차가움...        에세이
# 4      2016년 출간과 함께 베스트셀러에 오르며 뜨거운 관심을 받은 <랩걸-나무, 과학 ...       자연과학
# ...

# %%
best_date = pd.read_csv('goods_numbers_with_dates.csv')
best_date
# Out:
#        year  month  data_goods_no
# 0      2018      1       57717060
# 1      2018      1       54233937
# 2      2018      1       32972572
# 3      2018      1       30387696
# 4      2018      1       36390807
# ...     ...    ...            ...
# 77400  2024      6      126394099
# 77401  2024      6      124838794
# 77402  2024      6      119661061
# 77403  2024      6      116046987
# 77404  2024      6       82938415
#
# [77405 rows x 3 columns]

# %%
best_date.isnull().sum()
# Out:
# year             0
# month            0
# data_goods_no    0
# dtype: int64

# %%
date
# Out:
#               출간일         ID    year  month
# 0      2023-05-10  118755085  2023.0    5.0
# 1      2024-05-10  126395984  2024.0    5.0
# 2      2024-06-03  126791092  2024.0    6.0
# 3      2023-11-06  123317793  2023.0   11.0
# 4      2019-03-08   69724044  2019.0    3.0
# ...           ...        ...     ...    ...
# 297673 2027-07-24  128920663  2027.0    7.0
# 297674 2024-07-24  128920777  2024.0    7.0
# 297675 2024-07-23  128928568  2024.0    7.0
# 297676 2024-07-10  128928919  2024.0    7.0
# 297677 2024-07-15  128930900  2024.0    7.0
#
# [297678 rows x 4 columns]

# %%
date.isnull().sum()
# Out:
# 출간일      304
# ID         0
# year     304
# month    304
# dtype: int64

# %%
# 출간일 2017~2024 자르기
date = date[date['year'] != 2024] 
date = date[date['year'] >= 2017]
date
# Out:
#               출간일         ID    year  month
# 0      2023-05-10  118755085  2023.0    5.0
# 3      2023-11-06  123317793  2023.0   11.0
# 4      2019-03-08   69724044  2019.0    3.0
# 6      2023-08-30  122091079  2023.0    8.0
# 9      2023-11-10  123743926  2023.0   11.0
# ...           ...        ...     ...    ...
# 297089 2023-09-18  126822330  2023.0    9.0
# 297250 2023-12-10  127066962  2023.0   12.0
# 297634 2023-06-12  128818595  2023.0    6.0
# 297635 2023-06-12  128818647  2023.0    6.0
# 297673 2027-07-24  128920663  2027.0    7.0
#
# [100084 rows x 4 columns]

# %%
date.isnull().sum()
# Out:
# 출간일      0
# ID       0
# year     0
# month    0
# dtype: int64

# %%
# 출간일 2017~2024 자르기
# best_date에서 date의 ID와 data_goods_no가 일치하는 행 필터링 
best_date_filter_2017 = best_date[best_date["data_goods_no"].isin(date["ID"])]

best_date_filter_2017
# Out:
#        year  month  data_goods_no
# 1      2018      1       54233937
# 6      2018      1       46659527
# 7      2018      1       57817824
# 8      2018      1       57430679
# 9      2018      1       57430704
# ...     ...    ...            ...
# 77365  2024      6       22793441
# 77379  2024      6       46659527
# 77390  2024      6      121925411
# 77391  2024      6      120178685
# 77404  2024      6       82938415
#
# [16717 rows x 3 columns]

# %%
date_filter_2017_b = date[date["ID"].isin(best_date_filter_2017["data_goods_no"])]
date_filter_2017_b
# Out:
#               출간일         ID    year  month
# 0      2023-05-10  118755085  2023.0    5.0
# 3      2023-11-06  123317793  2023.0   11.0
# 4      2019-03-08   69724044  2019.0    3.0
# 6      2023-08-30  122091079  2023.0    8.0
# 9      2023-11-10  123743926  2023.0   11.0
# ...           ...        ...     ...    ...
# 294887 2023-12-25  124184330  2023.0   12.0
# 294903 2023-12-22  124201150  2023.0   12.0
# 294909 2023-12-20  124201716  2023.0   12.0
# 294948 2023-12-27  124226256  2023.0   12.0
# 294953 2023-12-21  124227999  2023.0   12.0
#
# [4501 rows x 4 columns]

# %%
for idx, row in best_date_filter_2017.iterrows():
    for mer_idx, mer_row in date_filter_2017_b.iterrows():
        if mer_row['ID'] == row['data_goods_no']:
            best_date_filter_2017.at[idx, '출간일'] = mer_row['출간일']
# Out:
# /tmp/ipykernel_479209/2466063951.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_date_filter_2017.at[idx, '출간일'] = mer_row['출간일']

# %%
best_date_filter_2017
# Out:
#        year  month  data_goods_no        출간일
# 1      2018      1       54233937 2017-10-27
# 6      2018      1       46659527 2017-09-22
# 7      2018      1       57817824 2018-01-08
# 8      2018      1       57430679 2017-12-12
# 9      2018      1       57430704 2017-12-12
# ...     ...    ...            ...        ...
# 77365  2024      6       22793441 2022-11-14
# 77379  2024      6       46659527 2017-09-22
# 77390  2024      6      121925411 2023-08-23
# 77391  2024      6      120178685 2023-07-27
# 77404  2024      6       82938415 2019-11-19
#
# [16717 rows x 4 columns]

# %%
best_date_filter_2017['year_출간일'] = best_date_filter_2017['출간일'].dt.year
# Out:
# /tmp/ipykernel_479209/246063368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_date_filter_2017['year_출간일'] = best_date_filter_2017['출간일'].dt.year

# %%
best_date_filter_2017_restore = best_date_filter_2017

# %%
best_date_filter_2017 = best_date_filter_2017[best_date_filter_2017['year'] >= best_date_filter_2017['year_출간일']]

# %%
best_date_filter_2017
# Out:
#        year  month  data_goods_no        출간일  year_출간일
# 1      2018      1       54233937 2017-10-27      2017
# 6      2018      1       46659527 2017-09-22      2017
# 7      2018      1       57817824 2018-01-08      2018
# 8      2018      1       57430679 2017-12-12      2017
# 9      2018      1       57430704 2017-12-12      2017
# ...     ...    ...            ...        ...       ...
# 77365  2024      6       22793441 2022-11-14      2022
# 77379  2024      6       46659527 2017-09-22      2017
# 77390  2024      6      121925411 2023-08-23      2023
# 77391  2024      6      120178685 2023-07-27      2023
# 77404  2024      6       82938415 2019-11-19      2019
#
# [16336 rows x 5 columns]

# %%
df_non_sorted_filtered = df_non_sorted

# %%
df_non_sorted_filtered
# Out:
#        index         도서 이름                                                줄거리  \
# 11853  61041  나는 야한 여자가 좋다  도덕보다는 본능을, 이성보다는 감성을쉽고 재미있게 읽히는 경쾌한 에세이, 21년만의...
# 51555  63780     뱀파이어의 별 2  '뱀파이어의 꽃' 그 마지막 입맞춤,영원불멸의 뱀파이어 로맨스!‘말해서는 안 돼. ...
# 51292  33906       수거물 폐기물  ■ 사랑의 기억을 모으고 나누고 버리고… 마음이 심플해지는 감정정리법!-카피라이터 ...
# 53713  36582        군인의 품격  군인엄마의, 희망군대 만들기 프로젝트아들에게도 엄마에게도, 637일간의 인생수업대한...
# 54414  66804           무녀굴  <한국 공포 문학 단편선>에 꾸준히 단편을 발표해 오며 실력을 닦아 온 신진오 작가...
# ...      ...           ...                                                ...
# 8570   65655  자기계발 코칭전문가 4  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 29816  68589      모두가 예술이다  계간 문예지 『시와세계』와 『현대불교신문』이 공동으로 제정한 <이상시문학상>은 시인...
# 8573   65658  자기계발 코칭전문가 1  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 8569   65654  자기계발 코칭전문가 5  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 6391   31192       이상 시 전집  한국문학사에서 유례를 찾기 힘들 만큼 실험적이고 전위적인 문학적 조형 언어로 ‘시각...
#
# ...

# %%
df_non_sorted_filtered_best = df_non_sorted_filtered[df_non_sorted_filtered['best'] == 'Y']
df_non_sorted_filtered_best
# Out:
#        index             도서 이름  \
# 51188  33777            합리적 남자
# 9847   58849     받은 만큼 복수하는 소녀
# 11831  61019    나, 있는 그대로 참 좋다
# 54459  66850           비탄의 문 1
# 54458  66849           비탄의 문 2
# ...      ...               ...
# 6385   31185           없음의 대명사
# 6305    6903                 풀
# 6378   31177                풀꽃
# 6392   31193  꽃샘바람에 흔들린다면 너는 꽃
# 6436   31239           수학자의 아침
#
#                                                      줄거리       장르     출판사  \
# 51188  남자와 여자가 짝짓기 대상을 선택하는 방식이 다른 것은 인간의 DNA에 깊이 새겨져...     자기계발     아니마
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡    문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이    허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# ...                                                  ...      ...     ...
# ...

# %%
df_non_sorted_filtered_best = df_non_sorted_filtered_best[df_non_sorted_filtered_best["ID"].isin(best_date_filter_2017["data_goods_no"])]
df_non_sorted_filtered_best
# Out:
#        index               도서 이름  \
# 9847   58849       받은 만큼 복수하는 소녀
# 11831  61019      나, 있는 그대로 참 좋다
# 54459  66850             비탄의 문 1
# 54458  66849             비탄의 문 2
# 9819   58821                베어타운
# ...      ...                 ...
# 6414   31215  너의 아름다움이 온통 글이 될까봐
# 6385   31185             없음의 대명사
# 6305    6903                   풀
# 6378   31177                  풀꽃
# 6392   31193    꽃샘바람에 흔들린다면 너는 꽃
#
#                                                      줄거리       장르     출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡    문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이    허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡    문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡    다산책방
# ...                                                  ...      ...     ...
# ...

# %%
df_non_sorted_filtered_nonbest =  df_non_sorted_filtered[df_non_sorted_filtered['best'] == 'N']
df_non_sorted_filtered_nonbest
# Out:
#        index         도서 이름                                                줄거리  \
# 11853  61041  나는 야한 여자가 좋다  도덕보다는 본능을, 이성보다는 감성을쉽고 재미있게 읽히는 경쾌한 에세이, 21년만의...
# 51555  63780     뱀파이어의 별 2  '뱀파이어의 꽃' 그 마지막 입맞춤,영원불멸의 뱀파이어 로맨스!‘말해서는 안 돼. ...
# 51292  33906       수거물 폐기물  ■ 사랑의 기억을 모으고 나누고 버리고… 마음이 심플해지는 감정정리법!-카피라이터 ...
# 53713  36582        군인의 품격  군인엄마의, 희망군대 만들기 프로젝트아들에게도 엄마에게도, 637일간의 인생수업대한...
# 54414  66804           무녀굴  <한국 공포 문학 단편선>에 꾸준히 단편을 발표해 오며 실력을 닦아 온 신진오 작가...
# ...      ...           ...                                                ...
# 8570   65655  자기계발 코칭전문가 4  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 29816  68589      모두가 예술이다  계간 문예지 『시와세계』와 『현대불교신문』이 공동으로 제정한 <이상시문학상>은 시인...
# 8573   65658  자기계발 코칭전문가 1  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 8569   65654  자기계발 코칭전문가 5  우리는 지금 어떤 시대에 살고 있는가? 포노 사피엔스 시대!(스마트폰 시대)20,0...
# 6391   31192       이상 시 전집  한국문학사에서 유례를 찾기 힘들 만큼 실험적이고 전위적인 문학적 조형 언어로 ‘시각...
#
# ...

# %%
df_non_sorted_filtered_finalmerged = pd.concat([df_non_sorted_filtered_nonbest, df_non_sorted_filtered_best])
df_non_sorted_filtered_finalmerged
# Out:
#        index               도서 이름  \
# 11853  61041        나는 야한 여자가 좋다
# 51555  63780           뱀파이어의 별 2
# 51292  33906             수거물 폐기물
# 53713  36582              군인의 품격
# 54414  66804                 무녀굴
# ...      ...                 ...
# 6414   31215  너의 아름다움이 온통 글이 될까봐
# 6385   31185             없음의 대명사
# 6305    6903                   풀
# 6378   31177                  풀꽃
# 6392   31193    꽃샘바람에 흔들린다면 너는 꽃
#
#                                                      줄거리       장르     출판사  \
# 11853  도덕보다는 본능을, 이성보다는 감성을쉽고 재미있게 읽히는 경쾌한 에세이, 21년만의...      에세이     북리뷰
# 51555  '뱀파이어의 꽃' 그 마지막 입맞춤,영원불멸의 뱀파이어 로맨스!‘말해서는 안 돼. ...  소설/시/희곡    테라스북
# 51292  ■ 사랑의 기억을 모으고 나누고 버리고… 마음이 심플해지는 감정정리법!-카피라이터 ...      에세이    폭스코너
# 53713  군인엄마의, 희망군대 만들기 프로젝트아들에게도 엄마에게도, 637일간의 인생수업대한...      에세이     더블엔
# 54414  <한국 공포 문학 단편선>에 꾸준히 단편을 발표해 오며 실력을 닦아 온 신진오 작가...  소설/시/희곡    황금가지
# ...                                                  ...      ...     ...
# ...

# %%
df_non_sorted_filtered_finalmerged['장르'].unique()
# Out:
# array(['에세이', '소설/시/희곡', '자기계발', '사회 정치'], dtype=object)

# %% [markdown]
# ##### Down Sampling

# %%
# 장르별 데이터 개수
genre_counts = df_non_sorted_filtered_nonbest['장르'].value_counts()

# 장르별 비율 계산 (전체 대비 비율)
genre_percentage = genre_counts / len(df_non_sorted_filtered_nonbest) * 100

# 결과 출력
genre_percentage
# Out:
# 장르
# 소설/시/희곡    60.065133
# 사회 정치      15.317788
# 에세이        14.438399
# 자기계발       10.178680
# Name: count, dtype: float64

# %%
# 베스트 셀러와 비베스트 셀러 데이터 분리
bestsellers = df_non_sorted_filtered_best
non_bestsellers = df_non_sorted_filtered_nonbest

# %% [markdown]
# 1:3

# %%
# 베스트 셀러 장르 비율
genre_distribution = {
    '소설/시/희곡': 60.065133,
    '에세이': 14.438399,
    '자기계발': 10.178680,
    '사회 정치': 15.317788
}

# 목표 총 개수
target_count = 4887

# 각 장르별 샘플 수 계산
samples_per_genre = {genre: int((percentage / 100) * target_count) for genre, percentage in genre_distribution.items()}

# 샘플 수가 해당 장르의 데이터 개수를 초과하지 않도록 조정
downsampled_non_bestsellers = pd.DataFrame()

for genre, num_samples in samples_per_genre.items():
    genre_data = non_bestsellers[non_bestsellers['장르'] == genre]
    if len(genre_data) < num_samples:
        num_samples = len(genre_data)  # 장르 데이터가 부족하면 전체 데이터 개수로 설정
    genre_samples = genre_data.sample(n=num_samples, replace=True)  # 필요시 중복 허용
    downsampled_non_bestsellers = pd.concat([downsampled_non_bestsellers, genre_samples])

# 최종 데이터프레임 생성
final_dataset_3 = pd.concat([bestsellers, downsampled_non_bestsellers])

# 결과 출력 및 확인
print("총 데이터 개수:", len(final_dataset_3))
final_dataset_3
# Out:
# 총 데이터 개수: 6514
#        index                   도서 이름  \
# 9847   58849           받은 만큼 복수하는 소녀
# 11831  61019          나, 있는 그대로 참 좋다
# 54459  66850                 비탄의 문 1
# 54458  66849                 비탄의 문 2
# 9819   58821                    베어타운
# ...      ...                     ...
# 37454  42768              언어학습과 사회통합
# 33021  37643            행복한 진로교육 멘토링
# 8681    9412                  뼈대 노동법
# 6192    6761                      종태
# 9560   10343  앨리스의 이상한 나라 경제학 퇴치 가이드
#
#                                                      줄거리       장르    출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡   문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이   허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡   다산책방
# ...

# %%
# 장르별 데이터 개수
genre_counts = final_dataset_3['장르'].value_counts()

# 장르별 비율 계산 (전체 대비 비율)
genre_percentage = genre_counts / len(final_dataset_3) * 100

# 결과 출력
genre_percentage
# Out:
# 장르
# 소설/시/희곡    54.313786
# 사회 정치      16.456862
# 에세이        16.287995
# 자기계발       12.941357
# Name: count, dtype: float64

# %% [markdown]
# 1:4

# %%
# 베스트 셀러 장르 비율
genre_distribution = {
    '소설/시/희곡': 60.065133,
    '에세이': 14.438399,
    '자기계발': 10.178680,
    '사회 정치': 15.317788
}

# 목표 총 개수
target_count = 6516

# 각 장르별 샘플 수 계산
samples_per_genre = {genre: int((percentage / 100) * target_count) for genre, percentage in genre_distribution.items()}

# 샘플 수가 해당 장르의 데이터 개수를 초과하지 않도록 조정
downsampled_non_bestsellers = pd.DataFrame()

for genre, num_samples in samples_per_genre.items():
    genre_data = non_bestsellers[non_bestsellers['장르'] == genre]
    if len(genre_data) < num_samples:
        num_samples = len(genre_data)  # 장르 데이터가 부족하면 전체 데이터 개수로 설정
    genre_samples = genre_data.sample(n=num_samples, replace=True)  # 필요시 중복 허용
    downsampled_non_bestsellers = pd.concat([downsampled_non_bestsellers, genre_samples])

# 최종 데이터프레임 생성
final_dataset_4 = pd.concat([bestsellers, downsampled_non_bestsellers])

# 결과 출력 및 확인
print("총 데이터 개수:", len(final_dataset_4))
final_dataset_4
# Out:
# 총 데이터 개수: 8143
#        index                      도서 이름  \
# 9847   58849              받은 만큼 복수하는 소녀
# 11831  61019             나, 있는 그대로 참 좋다
# 54459  66850                    비탄의 문 1
# 54458  66849                    비탄의 문 2
# 9819   58821                       베어타운
# ...      ...                        ...
# 22944  25661                가치를 만드는 사람들
# 32500  37068                   코칭수업 이야기
# 49453  61570                 세계의 특수부대 2
# 37739  43080  미래 사회를 위한 리터러시 교육의 다각화 모색
# 26496  30271                  인권사회학의 도전
#
#                                                      줄거리       장르      출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡     문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이     허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡     문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡     문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡     다산책방
# ...

# %%
# 장르별 데이터 개수
genre_counts = final_dataset_4['장르'].value_counts()

# 장르별 비율 계산 (전체 대비 비율)
genre_percentage = genre_counts / len(final_dataset_4) * 100

# 결과 출력
genre_percentage
# Out:
# 장르
# 소설/시/희곡    55.458676
# 사회 정치      16.234803
# 에세이        15.915510
# 자기계발       12.391011
# Name: count, dtype: float64

# %% [markdown]
# 1:5

# %%
# 베스트 셀러 장르 비율
genre_distribution = {
    '소설/시/희곡': 60.065133,
    '에세이': 14.438399,
    '자기계발': 10.178680,
    '사회 정치': 15.317788
}

# 목표 총 개수
target_count = 8145

# 각 장르별 샘플 수 계산
samples_per_genre = {genre: int((percentage / 100) * target_count) for genre, percentage in genre_distribution.items()}

# 샘플 수가 해당 장르의 데이터 개수를 초과하지 않도록 조정
downsampled_non_bestsellers = pd.DataFrame()

for genre, num_samples in samples_per_genre.items():
    genre_data = non_bestsellers[non_bestsellers['장르'] == genre]
    if len(genre_data) < num_samples:
        num_samples = len(genre_data)  # 장르 데이터가 부족하면 전체 데이터 개수로 설정
    genre_samples = genre_data.sample(n=num_samples, replace=True)  # 필요시 중복 허용
    downsampled_non_bestsellers = pd.concat([downsampled_non_bestsellers, genre_samples])

# 최종 데이터프레임 생성
final_dataset_5 = pd.concat([bestsellers, downsampled_non_bestsellers])

# 결과 출력 및 확인
print("총 데이터 개수:", len(final_dataset_5))
final_dataset_5
# Out:
# 총 데이터 개수: 9773
#        index                 도서 이름  \
# 9847   58849         받은 만큼 복수하는 소녀
# 11831  61019        나, 있는 그대로 참 좋다
# 54459  66850               비탄의 문 1
# 54458  66849               비탄의 문 2
# 9819   58821                  베어타운
# ...      ...                   ...
# 21305  23540         성공한 나라 불안한 시민
# 18429  20481        트럼프는 좌파일까 우파일까
# 9450   10233              한국의 국제보건
# 36083  41193            지금 만나러 갑니다
# 45552  55828  사장님, 이거 노동법 위반 아닌가요?
#
#                                                      줄거리       장르    출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡   문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이   허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡   다산책방
# ...                                                  ...      ...    ...
# ...

# %%
# 장르별 데이터 개수
genre_counts = final_dataset_5['장르'].value_counts()

# 장르별 비율 계산 (전체 대비 비율)
genre_percentage = genre_counts / len(final_dataset_5) * 100

# 결과 출력
genre_percentage
# Out:
# 장르
# 소설/시/희곡    56.226338
# 사회 정치      16.074900
# 에세이        15.675842
# 자기계발       12.022920
# Name: count, dtype: float64

# %% [markdown]
# #### Pre-Processing

# %%
# 판매가 열에서 숫자만 추출하여 정수형으로 변환
final_dataset_5['판매가'] = final_dataset_5['판매가'].str.replace('원', '').str.replace(',', '').astype(float)
final_dataset_5
# Out:
#        index                 도서 이름  \
# 9847   58849         받은 만큼 복수하는 소녀
# 11831  61019        나, 있는 그대로 참 좋다
# 54459  66850               비탄의 문 1
# 54458  66849               비탄의 문 2
# 9819   58821                  베어타운
# ...      ...                   ...
# 21305  23540         성공한 나라 불안한 시민
# 18429  20481        트럼프는 좌파일까 우파일까
# 9450   10233              한국의 국제보건
# 36083  41193            지금 만나러 갑니다
# 45552  55828  사장님, 이거 노동법 위반 아닌가요?
#
#                                                      줄거리       장르    출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡   문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이   허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡   다산책방
# ...                                                  ...      ...    ...
# ...

# %%
# 필요한 컬럼 선택
final_dataset_5 = final_dataset_5[["도서 이름", "줄거리", "장르", "출판사", "작가", "판매가", "best"]]

# 결과 출력
final_dataset_5
# Out:
#                       도서 이름  \
# 9847          받은 만큼 복수하는 소녀
# 11831        나, 있는 그대로 참 좋다
# 54459               비탄의 문 1
# 54458               비탄의 문 2
# 9819                   베어타운
# ...                     ...
# 21305         성공한 나라 불안한 시민
# 18429        트럼프는 좌파일까 우파일까
# 9450               한국의 국제보건
# 36083            지금 만나러 갑니다
# 45552  사장님, 이거 노동법 위반 아닌가요?
#
#                                                      줄거리       장르    출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡   문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이   허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡   다산책방
# ...                                                  ...      ...    ...
# 21305  최고와 최악이 공존하는 시간 속에 있는 우리의 삶은 얼마나 나아졌는가?디지털 전환,...    사회 정치   헤이북스
# ...

# %%
final_dataset_5.to_csv('final_dataset_5.csv', index=False)

# %%
final_dataset_5_copy = final_dataset_5

# %%
final_dataset_5
# Out:
#                       도서 이름  \
# 9847          받은 만큼 복수하는 소녀
# 11831        나, 있는 그대로 참 좋다
# 54459               비탄의 문 1
# 54458               비탄의 문 2
# 9819                   베어타운
# ...                     ...
# 21305         성공한 나라 불안한 시민
# 18429        트럼프는 좌파일까 우파일까
# 9450               한국의 국제보건
# 36083            지금 만나러 갑니다
# 45552  사장님, 이거 노동법 위반 아닌가요?
#
#                                                      줄거리       장르    출판사  \
# 9847   리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리...  소설/시/희곡   문학동네
# 11831  지금껏 애써 온 나를 위한 선물“충분히 반짝였던 2018년의 당신,내년에도 당신의 ...      에세이   허밍버드
# 54459  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 54458  미스터리와 판타지의 절묘한 융합장르의 벽을 깨는 미야베 월드수많은 말이 살아 움직이...  소설/시/희곡   문학동네
# 9819   눈부신 스토리텔러이자 인간 감정의 마스터『오베라는 남자』를 뛰어넘은프레드릭 배크만의...  소설/시/희곡   다산책방
# ...                                                  ...      ...    ...
# 21305  최고와 최악이 공존하는 시간 속에 있는 우리의 삶은 얼마나 나아졌는가?디지털 전환,...    사회 정치   헤이북스
# ...

# %% [markdown]
# - kobert embedding

# %%
from kobert_transformers import get_tokenizer, get_kobert_model
import torch
import pandas as pd
import numpy as np

# KoBERT 모델 및 토크나이저 불러오기
model = get_kobert_model()
tokenizer = get_tokenizer()

# 임베딩을 위한 함수 (KoBERT로 임베딩, 각 문장을 벡터로 변환)
def get_kobert_embeddings(text_list, max_length=128):
    embeddings = []
    
    for text in text_list:
        # 텍스트가 문자열이 아닐 경우 빈 문자열로 대체
        if not isinstance(text, str):
            text = ""
        
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        with torch.no_grad():
            outputs = model(**inputs)
        embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
        embeddings.append(embedding)
    
    return np.array(embeddings)

# 도서 이름, 줄거리, 작가, 출판사, 장르 각각에 대해 임베딩 수행
book_titles = final_dataset_5['도서 이름'].tolist()
summaries = final_dataset_5['줄거리'].tolist()
authors = final_dataset_5['작가'].tolist()
publishers = final_dataset_5['출판사'].tolist()
genres = final_dataset_5['장르'].tolist()

# 각 열에 대해 KoBERT 임베딩
book_title_embeddings = get_kobert_embeddings(book_titles)
summary_embeddings = get_kobert_embeddings(summaries)
author_embeddings = get_kobert_embeddings(authors)
publisher_embeddings = get_kobert_embeddings(publishers)
genre_embeddings = get_kobert_embeddings(genres)

# 임베딩 결합: 도서 이름, 줄거리, 작가, 출판사, 장르
final_embeddings = np.concatenate(
    (book_title_embeddings, summary_embeddings, author_embeddings, publisher_embeddings, genre_embeddings), axis=1
)

# 베스트셀러 여부 라벨 설정 (Y -> 1, N -> 0)
labels = final_dataset_5['best'].apply(lambda x: 1 if x == 'Y' else 0).values

# 임베딩 결과 및 라벨 확인
print(f"Final Embeddings Shape: {final_embeddings.shape}")
print(f"Labels Shape: {labels.shape}")
# Out:
# /home/alsghk01/다운로드/줄거리를 통한 도서 평점 예측2/myenv/lib64/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Final Embeddings Shape: (9773, 3840)
# Labels Shape: (9773,)

# %%
from kobert_transformers import get_tokenizer, get_kobert_model
import torch
import pandas as pd
import numpy as np

# KoBERT 모델 및 토크나이저 불러오기
model = get_kobert_model()
tokenizer = get_tokenizer()

# 임베딩을 위한 함수 (KoBERT로 임베딩, 각 문장을 벡터로 변환)
def get_kobert_embeddings(text_list, max_length=128):
    embeddings = []
    
    for text in text_list:
        # None 및 NaN 값을 빈 문자열로 처리하고, 그 외 값은 문자열로 변환
        if pd.isna(text):
            text = ""  # None 또는 NaN은 빈 문자열로 대체
        else:
            text = str(text)  # 그 외는 문자열로 변환
        
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        with torch.no_grad():
            outputs = model(**inputs)
        embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
        embeddings.append(embedding)
    
    return np.array(embeddings)


# 도서 이름, 줄거리, 작가, 출판사, 장르 각각에 대해 임베딩 수행
book_titles = final_dataset_5['도서 이름'].tolist()
summaries = final_dataset_5['줄거리'].tolist()
authors = final_dataset_5['작가'].tolist()
publishers = final_dataset_5['출판사'].tolist()
genres = final_dataset_5['장르'].tolist()

# 각 열에 대해 KoBERT 임베딩
book_title_embeddings = get_kobert_embeddings(book_titles)
summary_embeddings = get_kobert_embeddings(summaries)
author_embeddings = get_kobert_embeddings(authors)
publisher_embeddings = get_kobert_embeddings(publishers)
genre_embeddings = get_kobert_embeddings(genres)

# 임베딩 결합: 도서 이름, 줄거리, 작가, 출판사, 장르
final_embeddings = np.concatenate(
    (book_title_embeddings, summary_embeddings, author_embeddings, publisher_embeddings, genre_embeddings), axis=1
)

# 베스트셀러 여부 라벨 설정 (Y -> 1, N -> 0)
labels = final_dataset_5['best'].apply(lambda x: 1 if x == 'Y' else 0).values

# 임베딩 결과 및 라벨 확인
print(f"Final Embeddings Shape: {final_embeddings.shape}")
print(f"Labels Shape: {labels.shape}")

# %% [markdown]
# ##### Train-Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 데이터셋을 훈련 데이터와 테스트 데이터로 분리 (80% 훈련, 20% 테스트)
X_train, X_test, y_train, y_test = train_test_split(final_embeddings, labels, test_size=0.2, random_state=42)

# 데이터 정규화 (LSTM이나 RNN 모델을 위해 정규화가 필요할 수 있음)
scaler = StandardScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# 데이터 셋 크기 확인
print(f"X_train_normalized shape: {X_train_normalized.shape}")
print(f"X_test_normalized shape: {X_test_normalized.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train_normalized shape: (7818, 3840)
# X_test_normalized shape: (1955, 3840)
# y_train shape: (7818,)
# y_test shape: (1955,)

# %% [markdown]
# ##### Modeling

# %% [markdown]
# 1. RNN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
# Out:
# Epoch [1/10], Loss: 0.3501, Test Accuracy: 0.8563
# Epoch [2/10], Loss: 0.2308, Test Accuracy: 0.8691
# Epoch [3/10], Loss: 0.1824, Test Accuracy: 0.8614
# Epoch [4/10], Loss: 0.1445, Test Accuracy: 0.8609
# Epoch [5/10], Loss: 0.1227, Test Accuracy: 0.8742
# Epoch [6/10], Loss: 0.0961, Test Accuracy: 0.8568
# Epoch [7/10], Loss: 0.0926, Test Accuracy: 0.8696
# Epoch [8/10], Loss: 0.0794, Test Accuracy: 0.8558
# Epoch [9/10], Loss: 0.0733, Test Accuracy: 0.8726
# Epoch [10/10], Loss: 0.0625, Test Accuracy: 0.8639

# %% [markdown]
# 하이퍼파라미터 설정

# %%
input_size = X_train_normalized.shape[1]
hidden_size = 128
num_layers = 2
num_classes = 2  # 베스트셀러 여부 (Y/N)
batch_size = 64
learning_rate = 0.001
num_epochs = 100

# %% [markdown]
# 데이터 정의

# %%
# PyTorch 텐서로 변환
X_train_tensor = torch.tensor(X_train_normalized, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_normalized, dtype=torch.float32)

# 입력 데이터의 차원 변형
X_train_tensor = X_train_tensor.unsqueeze(1)  # 차원 추가 -> (batch_size, sequence_length=1, input_size)
X_test_tensor = X_test_tensor.unsqueeze(1)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# 데이터셋과 DataLoader 정의
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# 모델 정의

# %%
# RNN 모델 정의
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        h0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])  # 마지막 time step의 출력값 사용
        return out

# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        h0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        c0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# GRU 모델 정의
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        h0 = torch.zeros(num_layers, x.size(0), hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :])
        return out

# Transformer 모델 정의
class TransformerModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(TransformerModel, self).__init__()
        self.fc_in = nn.Linear(input_size, hidden_size)
        encoder_layer = nn.TransformerEncoderLayer(d_model=hidden_size, nhead=8)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.fc_out = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        x = self.fc_in(x)
        x = self.transformer_encoder(x)
        x = self.fc_out(x[:, -1, :])
        return x

# 모델 학습 함수
def train_model(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    for data, labels in train_loader:
        data, labels = data.to(device), labels.to(device)
        
        # Forward pass
        outputs = model(data)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    return total_loss / len(train_loader)

# %% [markdown]
# Early Stopping 클래스 정의

# %%
import numpy as np

class EarlyStopping:
    def __init__(self, patience=5, verbose=False):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, score):
        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %% [markdown]
# 성능 평가 함수 정의

# %%
def evaluate_model_full(model, test_loader, device):
    model.eval()
    all_labels = []
    all_preds = []
    
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    
    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='weighted')
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    
    # AUC-ROC
    try:
        auc_roc = roc_auc_score(pd.get_dummies(all_labels), pd.get_dummies(all_preds), multi_class='ovr')
    except:
        auc_roc = None  # AUC 계산 실패 시 None
    
    # Specificity 계산
    tn = np.sum((np.array(all_preds) == 0) & (np.array(all_labels) == 0))  # True Negatives
    fp = np.sum((np.array(all_preds) == 1) & (np.array(all_labels) == 0))  # False Positives
    specificity = tn / (tn + fp) if (tn + fp) > 0 else None
    
    return accuracy, f1, precision, recall, auc_roc, specificity

# %% [markdown]
# 모델 학습 및 평가

# %%
# Early Stopping 객체 생성
early_stopping = EarlyStopping(patience=5, verbose=True)

# 모델 학습 및 평가
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# RNN 모델 학습 및 평가
rnn_model = RNNModel(input_size, hidden_size, num_layers, num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn_model.parameters(), lr=learning_rate)

# 성능 평가 결과를 저장할 리스트
performance_metrics = []

for epoch in range(num_epochs):
    train_loss = train_model(rnn_model, train_loader, criterion, optimizer, device)
    
    accuracy, f1, precision, recall, auc_roc, specificity = evaluate_model_full(rnn_model, test_loader, device)
    
    performance_metrics.append({
        'Epoch': epoch + 1,
        'Loss': train_loss,
        'Accuracy': accuracy,
        'F1-score': f1,
        'Precision': precision,
        'Recall': recall,
        'AUC-ROC': auc_roc,
        'Specificity': specificity
    })
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, "
          f"Accuracy: {accuracy:.4f}, F1-score: {f1:.4f}, "
          f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC-ROC: {auc_roc:.4f}, Specificity: {specificity:.4f}")
    
    # Early Stopping 체크
    early_stopping(accuracy)
    if early_stopping.early_stop:
        print("Early stopping")
        break

# 성능 결과를 데이터프레임으로 변환
performance_df = pd.DataFrame(performance_metrics)
performance_df
# Out:
# Epoch [1/10], Loss: 0.3575, Accuracy: 0.8619, F1-score: 0.8510, Precision: 0.8491, Recall: 0.8619, AUC-ROC: 0.7010, Specificity: 0.9508
# Epoch [2/10], Loss: 0.2318, Accuracy: 0.8563, F1-score: 0.8501, Precision: 0.8468, Recall: 0.8563, AUC-ROC: 0.7167, Specificity: 0.9334
# EarlyStopping counter: 1 out of 5
# Epoch [3/10], Loss: 0.1791, Accuracy: 0.8691, F1-score: 0.8635, Precision: 0.8609, Recall: 0.8691, AUC-ROC: 0.7391, Specificity: 0.9409
# Epoch [4/10], Loss: 0.1455, Accuracy: 0.8680, F1-score: 0.8638, Precision: 0.8613, Recall: 0.8680, AUC-ROC: 0.7453, Specificity: 0.9359
# EarlyStopping counter: 1 out of 5
# Epoch [5/10], Loss: 0.1336, Accuracy: 0.8583, F1-score: 0.8584, Precision: 0.8585, Recall: 0.8583, AUC-ROC: 0.7585, Specificity: 0.9135
# EarlyStopping counter: 2 out of 5
# Epoch [6/10], Loss: 0.1209, Accuracy: 0.8691, F1-score: 0.8655, Precision: 0.8633, Recall: 0.8691, AUC-ROC: 0.7515, Specificity: 0.9340
# ...

# %% [markdown]
# 성능 시각화

# %%
plt.figure(figsize=(12, 10))

# 정확도 그래프
plt.subplot(3, 2, 1)
plt.plot(performance_df['Epoch'], performance_df['Accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# F1-score 그래프
plt.subplot(3, 2, 2)
plt.plot(performance_df['Epoch'], performance_df['F1-score'], label='F1-score', color='orange')
plt.title('Model F1-score')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.legend()

# Precision 그래프
plt.subplot(3, 2, 3)
plt.plot(performance_df['Epoch'], performance_df['Precision'], label='Precision', color='green')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# Recall 그래프
plt.subplot(3, 2, 4)
plt.plot(performance_df['Epoch'], performance_df['Recall'], label='Recall', color='red')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

# Specificity 그래프
plt.subplot(3, 2, 5)
plt.plot(performance_df['Epoch'], performance_df['Specificity'], label='Specificity', color='purple')
plt.title('Model Specificity')
plt.xlabel('Epoch')
plt.ylabel('Specificity')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))

# 정확도 그래프
plt.subplot(3, 2, 1)
plt.plot(performance_df['Epoch'], performance_df['Accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0.7, 1.0)  # y축 범위 설정
plt.legend()

# F1-score 그래프
plt.subplot(3, 2, 2)
plt.plot(performance_df['Epoch'], performance_df['F1-score'], label='F1-score', color='orange')
plt.title('Model F1-score')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.ylim(0.7, 1.0)  # y축 범위 설정
plt.legend()

# Precision 그래프
plt.subplot(3, 2, 3)
plt.plot(performance_df['Epoch'], performance_df['Precision'], label='Precision', color='green')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.ylim(0.7, 1.0)  # y축 범위 설정
plt.legend()

# Recall 그래프
plt.subplot(3, 2, 4)
plt.plot(performance_df['Epoch'], performance_df['Recall'], label='Recall', color='red')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.ylim(0.7, 1.0)  # y축 범위 설정
plt.legend()

# Specificity 그래프
plt.subplot(3, 2, 5)
plt.plot(performance_df['Epoch'], performance_df['Specificity'], label='Specificity', color='purple')
plt.title('Model Specificity')
plt.xlabel('Epoch')
plt.ylabel('Specificity')
plt.ylim(0.7, 1.0)  # y축 범위 설정
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. LSTM 모델 구현 및 학습

# %%
import torch.nn as nn
import torch.optim as optim

# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # 마지막 시퀀스의 출력을 가져옴
        return out

# %% [markdown]
# 하이퍼파라미터 설정

# %%
# 하이퍼파라미터 설정
input_size = X_train_tensor.shape[2]  # input_size는 데이터 차원에 맞춰 설정

# %%
# LSTM 모델 학습 및 평가
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

lstm_model = LSTMModel(input_size, hidden_size, num_layers, num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lstm_model.parameters(), lr=learning_rate)


for epoch in range(num_epochs):
    train_loss = train_model(lstm_model, train_loader, criterion, optimizer, device)
    
    accuracy, f1, precision, recall, auc_roc, specificity = evaluate_model_full(lstm_model, test_loader, device)
    
    performance_metrics.append({
        'Epoch': epoch + 1,
        'Loss': train_loss,
        'Accuracy': accuracy,
        'F1-score': f1,
        'Precision': precision,
        'Recall': recall,
        'AUC-ROC': auc_roc,
        'Specificity': specificity
    })
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, "
          f"Accuracy: {accuracy:.4f}, F1-score: {f1:.4f}, "
          f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC-ROC: {auc_roc:.4f}, Specificity: {specificity:.4f}")
    
    # Early Stopping 체크
    early_stopping(accuracy)
    if early_stopping.early_stop:
        print("Early stopping")
        break

# 성능 결과를 데이터프레임으로 변환
performance_df = pd.DataFrame(performance_metrics)
performance_df
# Out:
# Epoch [1/10], Loss: 0.3672, Accuracy: 0.8624, F1-score: 0.8385, Precision: 0.8520, Recall: 0.8624, AUC-ROC: 0.6518, Specificity: 0.9788
# EarlyStopping counter: 5 out of 5
# Early stopping
#     Epoch      Loss  Accuracy  F1-score  Precision    Recall   AUC-ROC  \
# 0       1  0.357488  0.861893  0.850975   0.849081  0.861893  0.700995
# 1       2  0.231850  0.856266  0.850078   0.846778  0.856266  0.716708
# 2       3  0.179109  0.869054  0.863512   0.860930  0.869054  0.739120
# 3       4  0.145533  0.868031  0.863753   0.861260  0.868031  0.745252
# 4       5  0.133642  0.858312  0.858392   0.858472  0.858312  0.758476
# 5       6  0.120870  0.869054  0.865520   0.863251  0.869054  0.751502
# 6       7  0.079367  0.865473  0.863319   0.861622  0.865473  0.754952
# 7       8  0.081204  0.860870  0.858203   0.856172  0.860870  0.744273
# 8       9  0.087032  0.864450  0.862109   0.860296  0.864450  0.752079
# 9      10  0.079942  0.868542  0.862883   0.860272  0.868542  0.737683
# ...

# %% [markdown]
# 성능 시각화

# %%
plt.figure(figsize=(12, 10))

# 정확도 그래프
plt.subplot(3, 2, 1)
plt.plot(performance_df['Epoch'], performance_df['Accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# F1-score 그래프
plt.subplot(3, 2, 2)
plt.plot(performance_df['Epoch'], performance_df['F1-score'], label='F1-score', color='orange')
plt.title('Model F1-score')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.legend()

# Precision 그래프
plt.subplot(3, 2, 3)
plt.plot(performance_df['Epoch'], performance_df['Precision'], label='Precision', color='green')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# Recall 그래프
plt.subplot(3, 2, 4)
plt.plot(performance_df['Epoch'], performance_df['Recall'], label='Recall', color='red')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

# Specificity 그래프
plt.subplot(3, 2, 5)
plt.plot(performance_df['Epoch'], performance_df['Specificity'], label='Specificity', color='purple')
plt.title('Model Specificity')
plt.xlabel('Epoch')
plt.ylabel('Specificity')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. KoBERT Transformer 모델

# %%
from transformers import BertModel, BertTokenizer

class TransformerModel(nn.Module):
    def __init__(self, num_classes):
        super(TransformerModel, self).__init__()
        self.bert = BertModel.from_pretrained('skt/kobert-base-v1')
        self.fc = nn.Linear(self.bert.config.hidden_size, num_classes)

    def forward(self, x):
        outputs = self.bert(x)
        out = self.fc(outputs.pooler_output)  # BERT의 pooled output 사용
        return out

# %%
transformer_model = TransformerModel(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(transformer_model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_loss = train_model(lstm_model, train_loader, criterion, optimizer, device)
    
    accuracy, f1, precision, recall, auc_roc, specificity = evaluate_model_full(lstm_model, test_loader, device)
    
    performance_metrics.append({
        'Epoch': epoch + 1,
        'Loss': train_loss,
        'Accuracy': accuracy,
        'F1-score': f1,
        'Precision': precision,
        'Recall': recall,
        'AUC-ROC': auc_roc,
        'Specificity': specificity
    })
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, "
          f"Accuracy: {accuracy:.4f}, F1-score: {f1:.4f}, "
          f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC-ROC: {auc_roc:.4f}, Specificity: {specificity:.4f}")
    
    # Early Stopping 체크
    early_stopping(accuracy)
    if early_stopping.early_stop:
        print("Early stopping")
        break

# 성능 결과를 데이터프레임으로 변환
performance_df = pd.DataFrame(performance_metrics)
performance_df
# Out:
# Epoch [1/10], Loss: 0.2296, Accuracy: 0.8624, F1-score: 0.8385, Precision: 0.8520, Recall: 0.8624, AUC-ROC: 0.6518, Specificity: 0.9788
# EarlyStopping counter: 6 out of 5
# Early stopping
#     Epoch      Loss  Accuracy  F1-score  Precision    Recall   AUC-ROC  \
# 0       1  0.357488  0.861893  0.850975   0.849081  0.861893  0.700995
# 1       2  0.231850  0.856266  0.850078   0.846778  0.856266  0.716708
# 2       3  0.179109  0.869054  0.863512   0.860930  0.869054  0.739120
# 3       4  0.145533  0.868031  0.863753   0.861260  0.868031  0.745252
# 4       5  0.133642  0.858312  0.858392   0.858472  0.858312  0.758476
# 5       6  0.120870  0.869054  0.865520   0.863251  0.869054  0.751502
# 6       7  0.079367  0.865473  0.863319   0.861622  0.865473  0.754952
# 7       8  0.081204  0.860870  0.858203   0.856172  0.860870  0.744273
# 8       9  0.087032  0.864450  0.862109   0.860296  0.864450  0.752079
# 9      10  0.079942  0.868542  0.862883   0.860272  0.868542  0.737683
# ...

# %%
plt.figure(figsize=(12, 10))

# 정확도 그래프
plt.subplot(3, 2, 1)
plt.plot(performance_df['Epoch'], performance_df['Accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# F1-score 그래프
plt.subplot(3, 2, 2)
plt.plot(performance_df['Epoch'], performance_df['F1-score'], label='F1-score', color='orange')
plt.title('Model F1-score')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.legend()

# Precision 그래프
plt.subplot(3, 2, 3)
plt.plot(performance_df['Epoch'], performance_df['Precision'], label='Precision', color='green')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# Recall 그래프
plt.subplot(3, 2, 4)
plt.plot(performance_df['Epoch'], performance_df['Recall'], label='Recall', color='red')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

# Specificity 그래프
plt.subplot(3, 2, 5)
plt.plot(performance_df['Epoch'], performance_df['Specificity'], label='Specificity', color='purple')
plt.title('Model Specificity')
plt.xlabel('Epoch')
plt.ylabel('Specificity')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. GRU

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.gru(x)  # GRU 레이어를 통과시킴
        out = out[:, -1, :]  # 마지막 시퀀스의 출력을 사용
        out = self.fc(out)
        return out

# GRU 모델 학습 및 평가
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

gru_model = GRUModel(input_size=X_train_tensor.shape[2], hidden_size=hidden_size, num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(gru_model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_loss = train_model(lstm_model, train_loader, criterion, optimizer, device)
    
    accuracy, f1, precision, recall, auc_roc, specificity = evaluate_model_full(lstm_model, test_loader, device)
    
    performance_metrics.append({
        'Epoch': epoch + 1,
        'Loss': train_loss,
        'Accuracy': accuracy,
        'F1-score': f1,
        'Precision': precision,
        'Recall': recall,
        'AUC-ROC': auc_roc,
        'Specificity': specificity
    })
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, "
          f"Accuracy: {accuracy:.4f}, F1-score: {f1:.4f}, "
          f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC-ROC: {auc_roc:.4f}, Specificity: {specificity:.4f}")
    
    # Early Stopping 체크
    early_stopping(accuracy)
    if early_stopping.early_stop:
        print("Early stopping")
        break

# 성능 결과를 데이터프레임으로 변환
performance_df = pd.DataFrame(performance_metrics)
performance_df
# Out:
# Epoch [1/10], Loss: 0.2281, Accuracy: 0.8624, F1-score: 0.8385, Precision: 0.8520, Recall: 0.8624, AUC-ROC: 0.6518, Specificity: 0.9788
# EarlyStopping counter: 8 out of 5
# Early stopping
#     Epoch      Loss  Accuracy  F1-score  Precision    Recall   AUC-ROC  \
# 0       1  0.357488  0.861893  0.850975   0.849081  0.861893  0.700995
# 1       2  0.231850  0.856266  0.850078   0.846778  0.856266  0.716708
# 2       3  0.179109  0.869054  0.863512   0.860930  0.869054  0.739120
# 3       4  0.145533  0.868031  0.863753   0.861260  0.868031  0.745252
# 4       5  0.133642  0.858312  0.858392   0.858472  0.858312  0.758476
# 5       6  0.120870  0.869054  0.865520   0.863251  0.869054  0.751502
# 6       7  0.079367  0.865473  0.863319   0.861622  0.865473  0.754952
# 7       8  0.081204  0.860870  0.858203   0.856172  0.860870  0.744273
# 8       9  0.087032  0.864450  0.862109   0.860296  0.864450  0.752079
# 9      10  0.079942  0.868542  0.862883   0.860272  0.868542  0.737683
# ...

# %%
plt.figure(figsize=(12, 10))

# 정확도 그래프
plt.subplot(3, 2, 1)
plt.plot(performance_df['Epoch'], performance_df['Accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# F1-score 그래프
plt.subplot(3, 2, 2)
plt.plot(performance_df['Epoch'], performance_df['F1-score'], label='F1-score', color='orange')
plt.title('Model F1-score')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.legend()

# Precision 그래프
plt.subplot(3, 2, 3)
plt.plot(performance_df['Epoch'], performance_df['Precision'], label='Precision', color='green')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# Recall 그래프
plt.subplot(3, 2, 4)
plt.plot(performance_df['Epoch'], performance_df['Recall'], label='Recall', color='red')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

# Specificity 그래프
plt.subplot(3, 2, 5)
plt.plot(performance_df['Epoch'], performance_df['Specificity'], label='Specificity', color='purple')
plt.title('Model Specificity')
plt.xlabel('Epoch')
plt.ylabel('Specificity')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. KoELECTRA

# %%
# 데이터 준비 - X_train과 X_test를 리스트로 변환
X_train_list = X_train.tolist()  # X_train이 텐서일 경우 리스트로 변환
X_test_list = X_test.tolist()     # X_test가 텐서일 경우 리스트로 변환

# %%
from transformers import ElectraTokenizer, ElectraModel

class KoELECTRAModel(nn.Module):
    def __init__(self, num_classes):
        super(KoELECTRAModel, self).__init__()
        self.electra = ElectraModel.from_pretrained('monologg/koelectra-base-v3-discriminator')
        self.fc = nn.Linear(self.electra.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.electra(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # [CLS] 토큰의 출력 사용
        return self.fc(pooled_output)

# KoELECTRA 모델 학습 및 평가
tokenizer_electra = ElectraTokenizer.from_pretrained('monologg/koelectra-base-v3-discriminator')

# %%
def encode_data_electra(texts):
    # None 및 NaN 값을 빈 문자열로 대체하고 문자열 리스트로 변환
    texts = [str(text) if text is not None and text is not np.nan else "" for text in texts]
    
    return tokenizer_electra(texts, padding=True, truncation=True, return_tensors='pt', max_length=128)

# %%
# 리스트 결합
combined_data = list(zip(book_titles, summaries, authors, publishers, genres))
combined_data
# Out:
# [('받은 만큼 복수하는 소녀',
#   '리스베트, 여자 교도소에 수감되다그리고 마침내 밝혀지는 용 문신의 비밀밀레니엄 시리즈 5권 『받은 만큼 복수하는 소녀』가 출간되었다. 밀레니엄 시리즈를 기획하고 3권까지 집필한 스티그 라르손의 갑작스러운 사망 후, 시리즈를 계승할 공식 작가로 지정된 다비드 라게르크란츠가 밀레니엄 4권 『거미줄에 걸린 소녀』(2017년 9월 출간)에 이어 발표한 신작이다.시리즈의 새 시작을 알린 4권 『거미줄에 걸린 소녀』가 전작 못지않은 사랑을 받으며 계승작의 자격을 입증한 후, 5권 『받은 만큼 복수하는 소녀』 역시 전 세계 40개국에 판권을 수출하며 성공작이라는 호평을 받았다. 현재 시리즈는 통산 1억 부 판매 돌파를 눈앞에 두고 있으며 총 6권까지 예정되어 있다.밀레니엄 5권 『받은 만큼 복수하는 소녀』에서는 시리즈의 주인공 리스베트의 등에 새겨진 거대한 용 문신의 비밀이 밝혀지는 가운데, 리스베트조차 몰랐던 새로운 음모와 인물들의 정체가 드러나면서 한층 복합적이고 흥미진진한 미스터리 추적이 펼쳐진다. 저자 라게르크란츠는 리스베트의 상징인 용 문신과 주요 인물들의 스토리를 의미심장하게 풀어냄과 동시에, 이슬람 사회의 여성 억압, 거짓과 진실의 경계가 모호해진 오늘날 미디어 환경의 실태, 스웨덴 사회의 인종차별 문제 등도 심도 있게 다루면서 밀레니엄 유니버스의 뼈대와 정신을 충실히 잇는 데 성공했다.',
#   '다비드 라게르크란츠',
#   '문학동네',
#   '소설/시/희곡'),
#  ('나, 있는 그대로 참 좋다',
# ...

# %%
# 데이터셋을 훈련 데이터와 테스트 데이터로 분리 (80% 훈련, 20% 테스트)
X_train, X_test, y_train, y_test = train_test_split(combined_data, labels, test_size=0.2, random_state=42)

# %%
# 데이터 준비 - X_train과 X_test를 리스트로 변환
X_train_list = X_train.tolist()  # X_train이 텐서일 경우 리스트로 변환
X_test_list = X_test.tolist()     # X_test가 텐서일 경우 리스트로 변환

# KoELECTRA 모델 학습 및 평가
X_train_electra = encode_data_electra(X_train_list)
X_test_electra = encode_data_electra(X_test_list)

train_dataset_electra = torch.utils.data.TensorDataset(X_train_electra['input_ids'], 
                                                        X_train_electra['attention_mask'], 
                                                        y_train_tensor)
test_dataset_electra = torch.utils.data.TensorDataset(X_test_electra['input_ids'], 
                                                       X_test_electra['attention_mask'], 
                                                       y_test_tensor)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 24
#      21 optimizer_electra = optim.Adam(electra_model.parameters(), lr=learning_rate)
#      23 for epoch in range(num_epochs):
# ---> 24     train_loss = train_model(electra_model, train_loader_electra, criterion, optimizer_electra, device)
#      25     test_accuracy = evaluate_model(electra_model, test_loader_electra, device)
#      26     print(f"KoELECTRA - Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
#
# Cell In[66], line 90, in train_model(model, train_loader, criterion, optimizer, device)
#      88 model.train()
#      89 total_loss = 0
# ---> 90 for data, labels in train_loader:
#      91     data, labels = data.to(device), labels.to(device)
#      93     # Forward pass
#
# ValueError: too many values to unpack (expected 2)

# %%
train_loader_electra = torch.utils.data.DataLoader(dataset=train_dataset_electra, batch_size=batch_size, shuffle=True)
test_loader_electra = torch.utils.data.DataLoader(dataset=test_dataset_electra, batch_size=batch_size, shuffle=False)

# KoELECTRA 모델 학습
electra_model = KoELECTRAModel(num_classes=num_classes).to(device)
optimizer_electra = optim.Adam(electra_model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_loss = train_model(electra_model, train_loader_electra, criterion, optimizer_electra, device)
    test_accuracy = evaluate_model(electra_model, test_loader_electra, device)
    print(f"KoELECTRA - Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# 6. KE-T5

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

class KET5Model(nn.Module):
    def __init__(self, num_classes):
        super(KET5Model, self).__init__()
        self.t5 = T5ForConditionalGeneration.from_pretrained('beomi/KET5-base')
        self.fc = nn.Linear(self.t5.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.t5(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # [CLS] 토큰의 출력 사용
        return self.fc(pooled_output)

# KE-T5 모델 학습 및 평가
tokenizer_t5 = T5Tokenizer.from_pretrained('beomi/KET5-base')

train_loader_t5 = torch.utils.data.DataLoader(dataset=train_dataset_t5, batch_size=batch_size, shuffle=True)
test_loader_t5 = torch.utils.data.DataLoader(dataset=test_dataset_t5, batch_size=batch_size, shuffle=False)

t5_model = KET5Model(num_classes=num_classes).to(device)
optimizer_t5 = optim.Adam(t5_model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_loss = train_model(t5_model, train_loader_t5, criterion, optimizer_t5, device)
    test_accuracy = evaluate_model(t5_model, test_loader_t5, device)
    print(f"KE-T5 - Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# 7. KoGPT-Trinity

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

class KoGPTModel(nn.Module):
    def __init__(self, num_classes):
        super(KoGPTModel, self).__init__()
        self.gpt = AutoModelForCausalLM.from_pretrained("beomi/Kogpt2")
        self.fc = nn.Linear(self.gpt.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.gpt(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # [CLS] 토큰의 출력 사용
        return self.fc(pooled_output)

# KoGPT-Trinity 모델 학습 및 평가
tokenizer_gpt = AutoTokenizer.from_pretrained("beomi/Kogpt2")

# 학습 및 평가용 데이터 준비
X_train_gpt = encode_data_electra(X_train_list)  # 같은 함수 사용
X_test_gpt = encode_data_electra(X_test_list)

train_dataset_gpt = torch.utils.data.TensorDataset(X_train_gpt['input_ids'], 
                                                   X_train_gpt['attention_mask'], 
                                                   y_train_tensor)
test_dataset_gpt = torch.utils.data.TensorDataset(X_test_gpt['input_ids'], 
                                                  X_test_gpt['attention_mask'], 
                                                  y_test_tensor)

train_loader_gpt = torch.utils.data.DataLoader(dataset=train_dataset_gpt, batch_size=batch_size, shuffle=True)
test_loader_gpt = torch.utils.data.DataLoader(dataset=test_dataset_gpt, batch_size=batch_size, shuffle=False)

gpt_model = KoGPTModel(num_classes=num_classes).to(device)
optimizer_gpt = optim.Adam(gpt_model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_loss = train_model(gpt_model, train_loader_gpt, criterion, optimizer_gpt, device)
    test_accuracy = evaluate_model(gpt_model, test_loader_gpt, device)
    print(f"KoGPT-Trinity - Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
